# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
coffee_dataframe = pd.read_csv("index_1.csv")

# %%
coffee_dataframe
# Out:
#             date datetime cash_type                 card  money    coffee_name
# 0     2024-03-01  15:50.5      card  ANON-0000-0000-0001  38.70          Latte
# 1     2024-03-01  19:22.5      card  ANON-0000-0000-0002  38.70  Hot Chocolate
# 2     2024-03-01  20:18.1      card  ANON-0000-0000-0002  38.70  Hot Chocolate
# 3     2024-03-01  46:33.0      card  ANON-0000-0000-0003  28.90      Americano
# 4     2024-03-01  48:14.6      card  ANON-0000-0000-0004  38.70          Latte
# ...          ...      ...       ...                  ...    ...            ...
# 3631  2025-03-23  34:54.9      card  ANON-0000-0000-1158  35.76     Cappuccino
# 3632  2025-03-23  43:37.4      card  ANON-0000-0000-1315  35.76          Cocoa
# 3633  2025-03-23  44:16.9      card  ANON-0000-0000-1315  35.76          Cocoa
# 3634  2025-03-23  47:28.7      card  ANON-0000-0000-1316  25.96      Americano
# 3635  2025-03-23  11:38.6      card  ANON-0000-0000-1275  35.76          Latte
#
# [3636 rows x 6 columns]

# %% [markdown]
# Scatter Plot

# %%
import numpy as np
plt.grid(True)

plt.scatter(coffee_dataframe["money"], coffee_dataframe['coffee_name'], color="red")
plt.title("Coffee Price Data")
plt.xlabel("money")
plt.ylabel("coffee_name")
plt.xticks(np.arange(0, max(coffee_dataframe["money"]) + 1, 5))  

# save chart
plt.savefig("charts/coffee_price_data.png", dpi=300)

#show chart
plt.show()

# %% [markdown]
# Histogram

# %%
plt.figure(figsize=(10, 6)) 

sns.histplot(data=coffee_dataframe, x="coffee_name")
plt.xticks(rotation=45, ha="right") 
sns.histplot(data=coffee_dataframe, x="coffee_name")
plt.title("Coffee Type Sale")
plt.xlabel("coffee_name")
plt.ylabel("count")

# save chart
plt.savefig("charts/coffee_type_sale.png", dpi=300)

#show chart
plt.show()

# %% [markdown]
# Kernel Density Plot

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(data=coffee_dataframe, x="money",fill=True,  hue="coffee_name",common_norm=False, palette="crest", alpha=0.2)

plt.title("Kernel Density Plot of money by coffee name")
plt.xlabel("money")
plt.ylabel("Density")

# save chart
plt.savefig("charts/kernel_density_plot.png", dpi=300)

#show chart
plt.show()

# %% [markdown]
# Violin Plot

# %%
sns.violinplot(x='cash_type', y='coffee_name', data=coffee_dataframe)
plt.title('Violin Plot of cash_type by coffee_name')

# save chart
plt.savefig("charts/violin_plot.png", dpi=300)

#show chart
plt.show()
